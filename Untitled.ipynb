# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('by-state-0430.csv', index_col='date')

# %%
df.head()
# Out:
#          state  positive  negative  pending  hospitalizedCurrently  \
# date
# 20200430    AK     355.0   18764.0      NaN                   19.0
# 20200430    AL    7019.0   80177.0      NaN                    NaN
# 20200430    AR    3255.0   45124.0      NaN                   95.0
# 20200430    AS       0.0       3.0     17.0                    NaN
# 20200430    AZ    7648.0   64138.0      NaN                  755.0
#
#           hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# 20200430                     NaN             NaN              NaN
# 20200430                   978.0             NaN            335.0
# 20200430                   402.0             NaN              NaN
# 20200430                     NaN             NaN              NaN
# 20200430                  1169.0           311.0              NaN
#
#           onVentilatorCurrently  onVentilatorCumulative  ...  hospitalized  \
# date                                                     ...
# ...

# %%
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#                               state  positive  negative  pending  \
# date
# 1970-01-01 00:00:00.020200430    AK     355.0   18764.0      NaN
# 1970-01-01 00:00:00.020200430    AL    7019.0   80177.0      NaN
# 1970-01-01 00:00:00.020200430    AR    3255.0   45124.0      NaN
# 1970-01-01 00:00:00.020200430    AS       0.0       3.0     17.0
# 1970-01-01 00:00:00.020200430    AZ    7648.0   64138.0      NaN
# ...                             ...       ...       ...      ...
# 1970-01-01 00:00:00.020200126    WA       1.0       NaN      NaN
# 1970-01-01 00:00:00.020200125    WA       1.0       NaN      NaN
# 1970-01-01 00:00:00.020200124    WA       1.0       NaN      NaN
# 1970-01-01 00:00:00.020200123    WA       1.0       NaN      NaN
# 1970-01-01 00:00:00.020200122    WA       1.0       NaN      NaN
#
#                                hospitalizedCurrently  hospitalizedCumulative  \
# date
# 1970-01-01 00:00:00.020200430                   19.0                     NaN
# ...
